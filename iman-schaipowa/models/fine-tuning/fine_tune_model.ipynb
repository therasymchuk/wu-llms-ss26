# %% [markdown]
# # Fine-tuning Phase
#
# This notebook covers the second approach in my project: fine-tuning a language model on Austrian tax law data.
#
# Unlike the inference notebook where I simply prompted GPT-4o-mini through an API, here I actually train a model to internalize the specific patterns, terminology, and structure of Austrian tax law. I use the Unsloth library, which is significantly faster and more memory-efficient than the standard Hugging Face `Trainer` used in a typical supervised fine-tuning (SFT) setup.
#
# The notebook is structured in three parts: fine-tuning the model, testing it on a single question, and running bulk inference across all 644 dataset rows to produce a results CSV for BERTScore evaluation.

# %% [markdown]
# ### Phase 1: Setup and Model Loading
#
# Here I load a base model that has already been compressed into 4-bit precision. This compression (called quantization) is what allows an 8-billion parameter model to fit onto a single T4 GPU. Without it the model would require far more VRAM than a standard GPU provides.
#
# I use Unsloth's `FastLanguageModel` instead of the standard HuggingFace `AutoModelForSequenceClassification` because it applies low-level kernel optimizations that reduce memory usage by roughly 70% and speed up training by 2x.

# %%
# !pip install "unsloth[colab-new]" "--upgrade"

import torch                           # PyTorch: the deep learning framework the model and training loop run on
import json                            # Used to open and parse my training_data.json file
from unsloth import FastLanguageModel  # Unsloth's optimized model loader, faster and more memory-efficient than standard HuggingFace
from datasets import Dataset           # Converts my JSON list into the HuggingFace Dataset format the SFTTrainer expects
from trl import SFTTrainer             # Supervised Fine-Tuning Trainer: manages the training loop automatically
from transformers import TrainingArguments  # Holds all training hyperparameters in one structured object
import os # Import os for environment variables

# Maximum token length per training example (question + answer combined).
# 2048 tokens is enough to cover even long Austrian tax law answers without truncating them.
max_seq_length = 2048

# I use Llama 3.1 8B pre-quantized to 4-bit precision via bitsandbytes.
# This is the same principle as loading a compressed model checkpoint:
# the weights are stored in 4-bit integers rather than 16-bit floats,
# which cuts VRAM usage roughly in half while keeping accuracy acceptable for fine-tuning.
model_id = "unsloth/Meta-Llama-3.1-8B-bnb-4bit"

# Workaround for HuggingFace TimeoutError as suggested by Unsloth
# !pip install modelscope
os.environ['UNSLOTH_USE_MODELSCOPE'] = '1'

# Load the model and tokenizer together.
# The tokenizer converts raw German text into token IDs the model can process,
# and converts the model's output token IDs back into readable text after generation.
# This is the same AutoTokenizer pattern used in standard HuggingFace SFT, but wrapped by Unsloth.
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_id,
    max_seq_length = max_seq_length,
    load_in_4bit = True,           # Keep the model in 4-bit format to stay within GPU memory limits
    token = "token",  # HuggingFace access token required to download gated models like Llama
)
# Out:
# Collecting unsloth[colab-new]
#   Downloading unsloth-2026.4.8-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 6.3 MB/s eta 0:00:00
# Collecting unsloth_zoo>=2026.4.8 (from unsloth[colab-new])
#   Downloading unsloth_zoo-2026.4.9-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (0.46.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (26.1)
# Requirement already satisfied: torch<2.11.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (2.10.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (0.25.0+cu128)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (5.9.5)
# Collecting tyro (from unsloth[colab-new])
#   Downloading tyro-1.0.13-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (5.29.6)
# Collecting xformers>=0.0.27.post2 (from unsloth[colab-new])
#   Downloading xformers-0.0.35-py39-none-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# Collecting bitsandbytes!=0.46.0,!=0.48.0,>=0.45.5 (from unsloth[colab-new])
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (3.6.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (0.2.1)
# Collecting datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1 (from unsloth[colab-new])
#   Downloading datasets-4.3.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (1.13.0)
# Requirement already satisfied: peft!=0.11.0,>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (0.19.1)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (1.11.0)
# Collecting hf_transfer (from unsloth[colab-new])
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (0.37.1)
# Collecting transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3 (from unsloth[colab-new])
#   Downloading transformers-5.5.0-py3-none-any.whl.metadata (32 kB)
# Collecting trl!=0.19.0,<=0.24.0,>=0.18.2 (from unsloth[colab-new])
#   Downloading trl-0.24.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (0.24.1)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (2.12.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (6.0.3)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from unsloth[colab-new]) (1.6.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.34.1->unsloth[colab-new]) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (3.28.0)
# Collecting pyarrow>=21.0.0 (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new])
#   Downloading pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth[colab-new]) (1.4.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth[colab-new]) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.11.0,>=2.4.0->unsloth[colab-new]) (1.13.1.3)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<2.11.0,>=2.4.0->unsloth[colab-new]) (1.5.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3->unsloth[colab-new]) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,!=4.57.4,!=4.57.5,!=5.0.0,!=5.1.0,<=5.5.0,>=4.51.3->unsloth[colab-new]) (0.22.2)
# Collecting torchao>=0.13.0 (from unsloth_zoo>=2026.4.8->unsloth[colab-new])
#   Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Collecting cut_cross_entropy (from unsloth_zoo>=2026.4.8->unsloth[colab-new])
#   Downloading cut_cross_entropy-25.1.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.4.8->unsloth[colab-new]) (11.3.0)
# Collecting msgspec (from unsloth_zoo>=2026.4.8->unsloth[colab-new])
#   Downloading msgspec-0.21.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from diffusers->unsloth[colab-new]) (8.7.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->unsloth[colab-new]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->unsloth[colab-new]) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->unsloth[colab-new]) (0.4.2)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->unsloth[colab-new]) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->unsloth[colab-new]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->unsloth[colab-new]) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->unsloth[colab-new]) (0.0.4)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth[colab-new]) (0.18.0)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth[colab-new]) (4.5.1)
# WARNING: unsloth 2026.4.8 does not provide the extra 'triton'
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (3.13.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->unsloth[colab-new]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->unsloth[colab-new]) (2.20.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<2.11.0,>=2.4.0->unsloth[colab-new]) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->diffusers->unsloth[colab-new]) (3.23.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<2.11.0,>=2.4.0->unsloth[colab-new]) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (2026.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (1.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->unsloth[colab-new]) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth[colab-new]) (1.17.0)
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 36.7 MB/s eta 0:00:00
# Downloading datasets-4.3.0-py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 45.3 MB/s eta 0:00:00
# Downloading transformers-5.5.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 101.2 MB/s eta 0:00:00
# Downloading trl-0.24.0-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 43.3 MB/s eta 0:00:00
# Downloading unsloth_zoo-2026.4.9-py3-none-any.whl (421 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.9/421.9 kB 40.7 MB/s eta 0:00:00
# Downloading xformers-0.0.35-py39-none-manylinux_2_28_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 108.0 MB/s eta 0:00:00
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 112.4 MB/s eta 0:00:00
# Downloading tyro-1.0.13-py3-none-any.whl (185 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.2/185.2 kB 21.2 MB/s eta 0:00:00
# Downloading unsloth-2026.4.8-py3-none-any.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 33.9 MB/s eta 0:00:00
# Downloading pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (48.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 45.6 MB/s eta 0:00:00
# Downloading torchao-0.17.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 105.2 MB/s eta 0:00:00
# Downloading cut_cross_entropy-25.1.1-py3-none-any.whl (22 kB)
# Downloading msgspec-0.21.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (225 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 24.4 MB/s eta 0:00:00
# Installing collected packages: torchao, pyarrow, msgspec, hf_transfer, tyro, xformers, cut_cross_entropy, bitsandbytes, datasets, transformers, trl, unsloth_zoo, unsloth
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# Successfully installed bitsandbytes-0.49.2 cut_cross_entropy-25.1.1 datasets-4.3.0 hf_transfer-0.1.9 msgspec-0.21.1 pyarrow-24.0.0 torchao-0.17.0 transformers-5.5.0 trl-0.24.0 tyro-1.0.13 unsloth-2026.4.8 unsloth_zoo-2026.4.9 xformers-0.0.35
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Collecting modelscope
#   Downloading modelscope-1.36.2-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from modelscope) (3.28.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from modelscope) (26.1)
# Requirement already satisfied: requests>=2.25 in /usr/local/lib/python3.12/dist-packages (from modelscope) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from modelscope) (75.2.0)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.12/dist-packages (from modelscope) (4.67.3)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.12/dist-packages (from modelscope) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25->modelscope) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25->modelscope) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.25->modelscope) (2026.2.25)
# Downloading modelscope-1.36.2-py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 114.1 MB/s eta 0:00:00
# Installing collected packages: modelscope
# Successfully installed modelscope-1.36.2
# ==((====))==  Unsloth 2026.4.8: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/235 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/459 [00:00<?, ?B/s]
# Unsloth: Will load unsloth/Meta-Llama-3.1-8B-bnb-4bit as a legacy tokenizer.

# %% [markdown]
# ### Phase 2: Applying LoRA (Low-Rank Adaptation)
#
# Standard SFT updates every parameter in the model. With 8 billion parameters that is impossible on a single GPU. LoRA solves this by freezing all original model weights and inserting small trainable adapter matrices at specific layers. Only these adapters are updated during training.
#
# This is conceptually similar to how `AutoModelForSequenceClassification` adds a new classification head on top of a frozen base model, except LoRA distributes the trainable capacity across multiple internal layers rather than adding it only at the output.

# %%
# Attach LoRA adapters to the frozen base model using Unsloth's PEFT integration
model = FastLanguageModel.get_peft_model(
    model,
    r = 16,  # Rank: the inner dimension of the adapter matrices.
             # A higher rank gives the adapters more capacity to learn but uses more memory.
             # 16 is a balanced starting point for domain-specific fine-tuning.

    # The layers where adapters are inserted.
    # q/k/v/o_proj are the attention projection matrices (same layers targeted in most LoRA papers).
    # gate/up/down_proj are the feed-forward network layers inside each transformer block.
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj"],

    lora_alpha = 16,   # Scaling factor applied to the adapter outputs before adding them to the base model.
                       # Matching lora_alpha to r keeps the effective learning rate stable.

    lora_dropout = 0,  # No dropout during adapter training. Unsloth is optimized for this setting.

    bias = "none",     # Bias terms in the base model are not updated, only the adapter matrices.

    # Gradient checkpointing saves VRAM by not storing all intermediate activations during the forward pass.
    # Instead they are recomputed on demand during backpropagation.
    # The 'unsloth' mode is their most memory-efficient implementation of this technique.
    use_gradient_checkpointing = "unsloth",
)
# Out:
# Unsloth 2026.4.8 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %% [markdown]
# ### Phase 3: Dataset Formatting
#
# In standard SFT (as in the lecture notebook), the dataset provides `sentence1`, `sentence2`, and a `label`, and the tokenizer handles formatting automatically. For generative fine-tuning the setup is different: the model receives a single formatted string and learns to predict the answer tokens that follow the question tokens.
#
# I use the Llama-3 prompt format with `### Frage:` and `### Antwort:` as delimiters. The `<|end_of_text|>` token at the end of each example tells the model where one training sample stops and the next begins, preventing it from generating text that bleeds across examples.

# %%
# Load my Austrian tax law training data from disk.
# The JSON file contains a list of question/answer dicts.
with open('training_data.json', 'r', encoding = 'utf-8') as f:
    json_data = json.load(f)

# Apply the Llama-3 prompt template to every example.
# The model learns the mapping: given '### Frage: ...' predict '### Antwort: ...'
# This is the generative equivalent of the tokenize_function in standard SFT.
def format_prompts(example):
    return {"text": f"### Frage: {example['question']}\n### Antwort: {example['answer']} <|end_of_text|>"}

# Convert the JSON list into a HuggingFace Dataset object (same class used in the lecture),
# then apply the formatting function across every row.
dataset = Dataset.from_list(json_data)
dataset = dataset.map(format_prompts)
# Out:
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]

# %% [markdown]
# ### Phase 4: Training Parameters
#
# The `TrainingArguments` here follow the same structure as in the standard SFT lecture notebook, with a few differences driven by the GPU memory constraints of working with a large generative model instead of a smaller classification model.

# %%
training_args = TrainingArguments(
    per_device_train_batch_size = 2,  # 2 examples per GPU step. Smaller than the lecture's batch of 4
                                      # because the generative model is much larger and needs more VRAM per example.

    gradient_accumulation_steps = 4,  # Accumulate gradients over 4 steps before updating weights.
                                      # Effective batch size = 2 x 4 = 8, matching common SFT practice
                                      # without needing to fit 8 examples in VRAM simultaneously.

    warmup_steps = 5,                 # Ramp the learning rate up gradually over the first 5 steps
                                      # to avoid large destabilizing updates at the very start of training.
                                      # The lecture used warmup_steps=500 over a much longer run.

    max_steps = 60,                   # Run for 60 gradient update steps total.
                                      # Kept short to avoid overfitting on a limited tax law dataset.

    learning_rate = 2e-4,             # Standard learning rate for LoRA fine-tuning.
                                      # Higher than typical full fine-tuning rates because only the small
                                      # adapter matrices are being updated, not the full model.

    fp16 = not torch.cuda.is_bf16_supported(),  # Use 16-bit floating point for speed.
                                                # bf16 is preferred on newer GPUs; fp16 is the fallback.

    logging_steps = 1,                # Log the training loss after every single step.

    optim = "adamw_8bit",             # 8-bit AdamW optimizer: functionally identical to standard AdamW
                                      # but compresses optimizer states to 8-bit, saving significant VRAM.

    output_dir = "outputs",           # Folder where intermediate training checkpoints are written.
)

# %% [markdown]
# ### Phase 5: The Actual Training
#
# The `SFTTrainer` is the generative equivalent of the `Trainer` class used in the lecture notebook. It takes the model, the formatted dataset, and the training arguments and runs the full training loop: forward pass, loss calculation, backpropagation, and weight update.
#
# The training ran for 60 steps. Below are 5 representative steps showing how the loss decreased as the model learned the Austrian tax law patterns:
#
# | Step | Training Loss |
# |------|---------------|
# | 1    | 2.142186      |
# | 15   | 0.924347      |
# | 30   | 0.420398      |
# | 45   | 0.301850      |
# | 60   | 0.225400      |

# %%
# SFTTrainer is the generative counterpart to the standard Trainer from the lecture.
# dataset_text_field points it to the 'text' column created by format_prompts,
# which contains the fully formatted training strings.
trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    args = training_args,
)

# Start the training run. The GPU computes the loss and updates the LoRA adapter weights each step.
trainer.train()
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=12):   0%|          | 0/100 [00:00<?, ? examples/s]
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 100 | Num Epochs = 5 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 41,943,040 of 8,072,204,288 (0.52% trained)
# `use_return_dict` is deprecated! Use `return_dict` instead!
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 02:42, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.142186</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.083776</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.111805</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.066067</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.793146</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.539089</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.269445</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.435477</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.292202</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.212772</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.163227</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.078735</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.118008</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.994228</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.924664</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.956764</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.837166</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.951856</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.952601</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.755941</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.813089</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.911744</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.660484</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.842461</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.782002</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.709184</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.616572</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.561367</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.625606</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.420345</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.555003</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.482563</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.552756</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.472749</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.558063</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.496392</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.581365</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.466709</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.468459</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.333274</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.338606</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.378844</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.375523</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.276573</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.388648</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.302040</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.374532</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.395507</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.288484</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.330693</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.354150</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.300128</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.259123</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.250472</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.277079</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.190292</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.254283</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.218748</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.211791</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.225009</td>
#     </tr>
#   </tbody>
# </table><p>
# Unsloth: Restored added_tokens_decoder metadata in outputs/checkpoint-60/tokenizer_config.json.
# TrainOutput(global_step=60, training_loss=0.7429977804422379, metrics={'train_runtime': 174.3192, 'train_samples_per_second': 2.754, 'train_steps_per_second': 0.344, 'total_flos': 1531682083356672.0, 'train_loss': 0.7429977804422379, 'epoch': 4.64})

# %% [markdown]
# ### Phase 6: Saving the Result
#
# I save only the LoRA adapter weights rather than the full model. The adapters hold all the Austrian tax law knowledge the model learned and are a small fraction of the full model size. They can be reloaded later by merging them back into the original base model.

# %%
# Save the trained LoRA adapter weights to a local folder
model.save_pretrained("llama3_1_tax_lora")

# Save the tokenizer alongside so both can be reloaded consistently for inference
tokenizer.save_pretrained("llama3_1_tax_lora")

print("Training complete! Model saved in 'llama3_1_tax_lora'")
# Out:
# Unsloth: Restored added_tokens_decoder metadata in llama3_1_tax_lora/tokenizer_config.json.
# Training complete! Model saved in 'llama3_1_tax_lora'

# %% [markdown]
# # (Bulk Inference) Production Phase
#
# The single-question test confirmed the model works. Now I run it across all 644 rows of my dataset to produce `fine_tuned_results.csv` for BERTScore evaluation. To handle this volume efficiently I use batching, which sends multiple questions to the GPU simultaneously rather than one at a time.

# %% [markdown]
# ### Phase 1: Environment and Pipeline Setup
#
# I configure the pipeline to distribute the model across all available GPUs automatically using `device_map='auto'`, and to use `bfloat16` precision which reduces memory usage while maintaining enough numerical accuracy for generation.

# %%
import pandas as pd
import torch
from transformers import pipeline
from tqdm import tqdm  # Wraps the loop to display a live progress bar in the console
import csv

# Load the full 644-row test dataset
test_df = pd.read_csv('dataset_clean.csv')

# Initialize the generation pipeline.
# device_map='auto' spreads the model layers across all available GPUs automatically.
# dtype=torch.bfloat16 reduces memory per activation while keeping generation quality high.
generator = pipeline(
    "text-generation",
    model = model,
    tokenizer = tokenizer,
    device_map = "auto",
    dtype = torch.bfloat16
)

# %% [markdown]
# ### Phase 2: Batching Strategy
#
# Processing questions one at a time leaves the GPU underutilized between calls. Batching sends a group of questions in a single forward pass, keeping the GPU fully occupied and reducing total runtime significantly. A batch size of 8 means 8 questions are processed simultaneously per step.

# %%
batch_size = 8  # Number of questions processed simultaneously per GPU forward pass
results = []    # Collects id/answer dicts as the loop progresses

print(f"Starting inference for {len(test_df)} rows...")

# Iterate through the dataset in steps of 8 (indices 0, 8, 16, 24 and so on)
for i in tqdm(range(0, len(test_df), batch_size)):

    # Slice out the current batch of up to 8 rows
    batch = test_df.iloc[i:i+batch_size]

    # Format every prompt in the batch using the same structure used during training
    prompts = [f"### Frage:\n{row['prompt']}\n\n### Antwort:\n" for _, row in batch.iterrows()]

    # Run generation on the current batch.
    # max_new_tokens=150 gives enough room for a full legal citation and explanation.
    # do_sample=False: greedy decoding, always picks the most likely next token.
    # pad_token_id prevents warnings when sequences in the batch have different lengths.
    outputs = generator(
        prompts,
        max_new_tokens = 150,
        do_sample = False,
        pad_token_id = tokenizer.eos_token_id,
        batch_size = batch_size
    )

    # Loop through the 8 outputs from this batch
    for j, output in enumerate(outputs):
        generated_text = output[0]['generated_text']

        # Split at the answer marker and keep only what comes after it
        clean_answer = generated_text.split("### Antwort:\n")[-1].strip()

        # Store the answer with its original question ID to enable correct merging during evaluation
        results.append({
            "id": batch.iloc[j]['id'],
            "answer": clean_answer
        })
# Out:
# Starting inference for 643 rows...
#   0%|          | 0/81 [00:00<?, ?it/s]Passing `generation_config` together with generation-related arguments=({'do_sample', 'pad_token_id', 'cache_implementation', 'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:172: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:202: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:254: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:202: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:254: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
#   1%|          | 1/81 [00:24<32:53, 24.67s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:172: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
#   2%|▏         | 2/81 [00:45<29:41, 22.55s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#   4%|▎         | 3/81 [01:34<45:03, 34.66s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#   5%|▍         | 4/81 [01:51<35:21, 27.55s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#   6%|▌         | 5/81 [02:13<32:34, 25.72s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#   7%|▋         | 6/81 [02:42<33:27, 26.77s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#   9%|▊         | 7/81 [03:10<33:34, 27.23s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  10%|▉         | 8/81 [03:30<30:01, 24.68s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  11%|█         | 9/81 [03:51<28:21, 23.63s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  12%|█▏        | 10/81 [04:12<26:55, 22.75s/it]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  14%|█▎        | 11/81 [04:31<25:14, 21.64s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  15%|█▍        | 12/81 [04:49<23:42, 20.62s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  16%|█▌        | 13/81 [05:05<21:54, 19.33s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  17%|█▋        | 14/81 [05:23<20:59, 18.79s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  19%|█▊        | 15/81 [05:41<20:15, 18.41s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  20%|█▉        | 16/81 [06:00<20:16, 18.72s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  21%|██        | 17/81 [06:19<19:53, 18.65s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  22%|██▏       | 18/81 [06:57<25:50, 24.62s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  23%|██▎       | 19/81 [07:27<26:57, 26.09s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  25%|██▍       | 20/81 [08:03<29:45, 29.27s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  26%|██▌       | 21/81 [08:21<25:41, 25.70s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  27%|██▋       | 22/81 [08:38<22:55, 23.32s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  28%|██▊       | 23/81 [08:55<20:30, 21.21s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  30%|██▉       | 24/81 [09:12<18:56, 19.93s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  31%|███       | 25/81 [09:30<18:13, 19.52s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  32%|███▏      | 26/81 [09:48<17:29, 19.08s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  33%|███▎      | 27/81 [10:15<19:12, 21.34s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  35%|███▍      | 28/81 [10:36<18:49, 21.31s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  36%|███▌      | 29/81 [10:59<18:46, 21.67s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  37%|███▋      | 30/81 [11:18<17:52, 21.03s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  38%|███▊      | 31/81 [11:37<16:55, 20.32s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  40%|███▉      | 32/81 [11:52<15:23, 18.85s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  41%|████      | 33/81 [12:10<14:46, 18.46s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  42%|████▏     | 34/81 [12:23<13:21, 17.05s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  43%|████▎     | 35/81 [12:42<13:31, 17.63s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  44%|████▍     | 36/81 [13:05<14:19, 19.10s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  46%|████▌     | 37/81 [13:39<17:14, 23.51s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  47%|████▋     | 38/81 [14:15<19:40, 27.45s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  48%|████▊     | 39/81 [14:34<17:16, 24.67s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  49%|████▉     | 40/81 [14:49<14:55, 21.83s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  51%|█████     | 41/81 [15:09<14:09, 21.23s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  52%|█████▏    | 42/81 [15:57<19:00, 29.25s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  53%|█████▎    | 43/81 [16:14<16:21, 25.83s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  54%|█████▍    | 44/81 [16:28<13:34, 22.00s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  56%|█████▌    | 45/81 [16:43<12:04, 20.12s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  57%|█████▋    | 46/81 [16:58<10:44, 18.41s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  58%|█████▊    | 47/81 [17:19<10:52, 19.20s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  59%|█████▉    | 48/81 [17:34<09:57, 18.12s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  60%|██████    | 49/81 [17:50<09:20, 17.53s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  62%|██████▏   | 50/81 [18:10<09:19, 18.06s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  63%|██████▎   | 51/81 [18:29<09:11, 18.40s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  64%|██████▍   | 52/81 [18:50<09:15, 19.16s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  65%|██████▌   | 53/81 [19:31<11:58, 25.66s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  67%|██████▋   | 54/81 [20:04<12:33, 27.90s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  68%|██████▊   | 55/81 [20:55<15:04, 34.80s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  69%|██████▉   | 56/81 [21:13<12:24, 29.79s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  70%|███████   | 57/81 [21:28<10:07, 25.29s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  72%|███████▏  | 58/81 [21:48<09:08, 23.84s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  73%|███████▎  | 59/81 [22:04<07:50, 21.40s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  74%|███████▍  | 60/81 [22:20<06:55, 19.78s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  75%|███████▌  | 61/81 [22:38<06:25, 19.30s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  77%|███████▋  | 62/81 [23:02<06:31, 20.60s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  78%|███████▊  | 63/81 [23:25<06:25, 21.44s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  79%|███████▉  | 64/81 [23:47<06:05, 21.48s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  80%|████████  | 65/81 [24:10<05:53, 22.06s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:71: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:281: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:202: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:254: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
#  81%|████████▏ | 66/81 [24:30<05:19, 21.31s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:172: FutureWarning: The attention mask API under `transformers.modeling_attn_mask_utils` (`AttentionMaskConverter`) is deprecated and will be removed in Transformers v5.10. Please use the new API in `transformers.masking_utils`.
#   warnings.warn(DEPRECATION_MESSAGE, FutureWarning)
#  83%|████████▎ | 67/81 [24:46<04:38, 19.87s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  84%|████████▍ | 68/81 [25:13<04:46, 22.03s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  85%|████████▌ | 69/81 [25:34<04:18, 21.54s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  86%|████████▋ | 70/81 [25:55<03:56, 21.49s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  88%|████████▊ | 71/81 [26:13<03:24, 20.46s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  89%|████████▉ | 72/81 [26:30<02:54, 19.35s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  90%|█████████ | 73/81 [26:47<02:29, 18.68s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  91%|█████████▏| 74/81 [27:07<02:14, 19.16s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  93%|█████████▎| 75/81 [27:22<01:46, 17.78s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  94%|█████████▍| 76/81 [27:42<01:32, 18.40s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  95%|█████████▌| 77/81 [27:57<01:10, 17.57s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  96%|█████████▋| 78/81 [28:17<00:54, 18.27s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  98%|█████████▊| 79/81 [28:36<00:36, 18.36s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
#  99%|█████████▉| 80/81 [28:50<00:17, 17.28s/it]Both `max_new_tokens` (=150) and `max_length`(=131072) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# 100%|██████████| 81/81 [29:03<00:00, 21.53s/it]

# %% [markdown]
# ### Phase 3: The Generation Engine
#
# The generator processes all 8 prompts in the current batch in a single forward pass. Setting `do_sample=False` uses greedy decoding, meaning the model always picks the highest-probability next token. This makes the output deterministic and consistent, which is important for reproducible evaluation.

# %% [markdown]
# ### Phase 4: Data Cleaning and Extraction
#
# Each output contains the full prompt plus the generated answer as one string. I strip the prompt portion from every output so only the clean answer is stored, then map it back to its original question ID so the results can be correctly merged with ground truth during BERTScore evaluation.

# %% [markdown]
# ### Phase 5: Secure Export
#
# I save the results using `csv.QUOTE_ALL`, which wraps every cell in double quotes. Austrian legal text frequently contains commas inside law citations such as `§ 2, Abs. 1`. Without quoting those commas would be misread as column separators, corrupting the CSV structure.

# %%
output_file = 'fine_tuned_results.csv'
results_df = pd.DataFrame(results)

# QUOTE_ALL wraps every cell in double quotes to protect commas inside legal citations
results_df.to_csv(output_file, index = False, quoting = csv.QUOTE_ALL, encoding = 'utf-8')

print(f"\nSuccess! Inference complete. File saved as: {output_file}")
# Out:
# Success! Inference complete. File saved as: fine_tuned_results.csv
